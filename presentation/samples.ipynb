# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Code in the presentation slides "Modeling the Earth with Fatiando a Terra" - SciPy Conference 2013
#
# These are the code samples used in my slides. The notebook for the code samples in the conference proceedings can be found [on figshare](http://dx.doi.org/10.6084/m9.figshare.708390).

# %% [markdown]
# ## Forward gravity modeling

# %%
from fatiando import gridder, gravmag
from fatiando.mesher import Prism
model = [Prism(-500,500,-500,500,200,1700,{'density':1000})]
area = [-1000, 1000, -1000, 1000]
x, y, z = gridder.scatter(area, 100, z=-1)
g = gravmag.prism.gz(x, y, z, model)

# %%
from fatiando.vis import mpl
mpl.figure()
mpl.axis('scaled')
mpl.contourf(y, x, g, (100,100), 30, interp=True)
mpl.plot(y, x, '.k')
mpl.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x51d0758>
